# %%
import train
from transformer import Model
import numbers_data
from torch.optim import Adam

vocab_size = len(numbers_data.VOCAB)
model = Model(vocab_size, d=128, f=512, layers=6, q_heads=8, kv_heads=8)
# Out:
# /Users/andrew/Desktop/transformer_impl/.venv/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %%
optim = Adam(model.parameters(), lr=1e-3)
train.train(model, optim, save_freq=50, mini_batch_size=64, batch_size=512)
# Out:
# Epoch 0 training loss: 1.2862579214572907
# Epoch 0 training loss: 0.8431731700897217
# Epoch 0 training loss: 0.7993010699748992
# Epoch 0 training loss: 0.7843202328681946
# Epoch 0 training loss: 0.7772658431529998
# Epoch 0 training loss: 0.7686053276062011
# Epoch 0 training loss: 0.7623009550571441
# Epoch 0 training loss: 0.7517501235008239
# Epoch 0 training loss: 0.7416513109207153
# Epoch 0 training loss: 0.7354150366783142
# Epoch 0 training loss: 0.7286356866359711
# Epoch 0 training loss: 0.724882869720459
# Epoch 0 training loss: 0.7213597857952118
# Epoch 0 training loss: 0.718281774520874
# Epoch 0 training loss: 0.7151783609390259
# Epoch 0 training loss: 0.7131129491329193
# Epoch 0 training loss: 0.709859367609024
# Epoch 0 training loss: 0.706552141904831
# Epoch 0 training loss: 0.7047779250144959
# Epoch 0 training loss: 0.7037156009674073
# Epoch 0 training loss: 0.7024317109584808
# Epoch 0 training loss: 0.6982256162166596
# Epoch 0 training loss: 0.697123064994812
# Epoch 0 training loss: 0.6936280870437622
# Epoch 0 training loss: 0.6883692419528962
# Epoch 0 training loss: 0.6898636507987976
# Epoch 0 training loss: 0.6825594246387482
# Epoch 0 training loss: 0.6803873860836029
# Epoch 0 training loss: 0.6767198050022125
# Epoch 0 training loss: 0.6730771946907044
# Epoch 0 training loss: 0.6704715430736542
# Epoch 0 training loss: 0.6672940218448639
# Epoch 0 training loss: 0.6655917811393738
# Epoch 0 training loss: 0.6646881067752838
# Epoch 0 training loss: 0.657317225933075
# Epoch 0 training loss: 0.6541355764865875
# Epoch 0 training loss: 0.6488379573822022
# Epoch 0 training loss: 0.6453981256484985
# Epoch 0 training loss: 0.6417545664310456
# Epoch 0 training loss: 0.6403333139419556
# Epoch 0 training loss: 0.6366679811477661
# Epoch 0 training loss: 0.6337023961544037
# Epoch 0 training loss: 0.629647033214569
# Epoch 0 training loss: 0.6293007850646972
# Epoch 0 training loss: 0.6258745408058166
# Epoch 0 training loss: 0.6233322286605835
# Epoch 0 training loss: 0.6222774720191956
# Epoch 0 training loss: 0.6194073617458343
# Epoch 0 training loss: 0.616186978816986
# Epoch 0 training loss: 0.6129384136199951
# Epoch 0 training loss: 0.612697331905365

# %%
import torch
ans_pos = numbers_data.EQUALS_POS

batch, tokens, attn_mask = numbers_data.create_addition_batch(1, 32)
attn_mask = torch.stack(attn_mask)
x = torch.tensor(tokens)
y = torch.tensor(tokens)[:, ans_pos:]
pred = model(x, attn_mask)

print("expr: ", batch, len(batch[0]))
print("expected: ", y)
# print("logits: ", pred)

print("prediction: ", model.sample_pred_best(pred)[:, ans_pos-1:-1])
# Out:
# expr:  ['60222+52015NNN=112237NNNNNNNNNNN'] 32
# expected:  tensor([[ 1,  1,  2,  2,  3,  7, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]])
# prediction:  tensor([[ 2,  1,  2,  6,  5,  0, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]])

# %%
batch_size = 4
n_tokens = 32
batch, tokens = numbers_data.create_addition_batch(batch_size, n_tokens)
loss_mask = torch.ones([batch_size, n_tokens])
for i in range(batch_size):
    idx = batch[i].index('=')
    loss_mask[i][:idx+1] = 0

print(batch)
print(loss_mask)

# %%
mask = torch.tensor([0, -10, 0, -10, -10])
print(mask)

a = mask.repeat(5, 1)
print(a)
print(a + a.T)

# %%
expr = "1234+1234=2468"
print(numbers_data.tokenize(expr))

# %%
a = torch.ones((32, 1))
print(a * numbers_data.PAD_ID)
